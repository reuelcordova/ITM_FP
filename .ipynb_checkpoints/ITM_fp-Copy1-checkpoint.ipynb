# %% [markdown]
# # Reading the Data

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /Users/matcordova/anaconda3/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: pandas>=0.25 in /Users/matcordova/anaconda3/lib/python3.10/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /Users/matcordova/anaconda3/lib/python3.10/site-packages (from seaborn) (3.7.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /Users/matcordova/anaconda3/lib/python3.10/site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pillow>=6.2.0 in /Users/matcordova/anaconda3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/matcordova/anaconda3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/matcordova/anaconda3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/matcordova/anaconda3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/matcordova/anaconda3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /Users/matcordova/anaconda3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (22.0)
# Requirement already satisfied: cycler>=0.10 in /Users/matcordova/anaconda3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/matcordova/anaconda3/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: pytz>=2020.1 in /Users/matcordova/anaconda3/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/matcordova/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
df = pd.read_csv('Family-Income-and-Expenditure.csv')

# %% [markdown]
# # Sorting and Filtering the Data

# %%
new_df = df.loc[:,['Total Household Income','Region', 'Total Food Expenditure','Bread and Cereals Expenditure', 'Total Rice Expenditure',
       'Meat Expenditure', 'Total Fish and  marine products Expenditure',
       'Fruit Expenditure', 'Vegetables Expenditure',
       'Restaurant and hotels Expenditure', 'Alcoholic Beverages Expenditure',
       'Tobacco Expenditure', 'Clothing, Footwear and Other Wear Expenditure',
       'Housing and water Expenditure', 'Imputed House Rental Value',
       'Medical Care Expenditure', 'Transportation Expenditure',
       'Communication Expenditure', 'Education Expenditure',
       'Miscellaneous Goods and Services Expenditure','Special Occasions Expenditure', 'Crop Farming and Gardening expenses','Household Head Sex','Household Head Highest Grade Completed',
       'Household Head Occupation','Household Head Class of Worker',
        'Number of Car, Jeep, Van','Number of Motorcycle/Tricycle', 'Number of Motorized Banca',
]]
new_df['Vice Expenditures'] = df.loc[:,['Alcoholic Beverages Expenditure','Tobacco Expenditure']].sum(axis=1)
new_df['Discretionary Expenses'] = df.loc[:,['Restaurant and hotels Expenditure','Special Occasions Expenditure']].sum(axis=1)
new_df['New Total Food Expenditure'] = df.loc[:,['Bread and Cereals Expenditure', 'Total Rice Expenditure',
       'Meat Expenditure', 'Total Fish and  marine products Expenditure',
       'Fruit Expenditure', 'Vegetables Expenditure',]].sum(axis=1)
new_df = new_df.drop(['Bread and Cereals Expenditure', 'Total Rice Expenditure',
       'Meat Expenditure', 'Total Fish and  marine products Expenditure',
       'Fruit Expenditure', 'Vegetables Expenditure','Alcoholic Beverages Expenditure',
       'Tobacco Expenditure','Restaurant and hotels Expenditure','Special Occasions Expenditure'], axis = 1)
new_df = new_df.sort_values('Total Household Income')
rating = []
for row in new_df['Household Head Highest Grade Completed']:
    if row == 'Preschool':
        rating.append('Preschool')
    elif row == 'Grade 1':
        rating.append('Preschool')
    elif row == 'Grade 2':
        rating.append('Preschool')
    elif row == 'Grade 3':
        rating.append('Preschool')
    elif row == 'Grade 4':
        rating.append('Preschool')
    elif row == 'Grade 5':
        rating.append('Preschool')
    elif row == 'Grade 6':
        rating.append('Preschool')
    elif row == 'First Year High school':
        rating.append('Grade School')
    elif row == 'Second Year High School':
        rating.append('Grade School')
    elif row == 'Third Year High School':
        rating.append('Grade School')
    elif row == 'First Year College':
        rating.append('High School')
    elif row == 'Second Year College':
        rating.append('High School')
    elif row == 'Third Year College':
        rating.append('High School')
    elif row == 'Elementary Graduate':
        rating.append('Grade School')
    elif row == 'High School Graduate':
        rating.append('High School')
    elif row == 'No Grade Completed':
        rating.append('No Grade Completed')
    else:
        rating.append('College and up')       
new_df['New Highest Household Head Grade Completed'] = rating

# %%
new_df.head(5)
# Out:
#        Total Household Income                 Region  Total Food Expenditure  \
# 9474                    11285  VII - Central Visayas                   14709
# 22638                   11988                    CAR                    6781
# 31209                   12039       V - Bicol Region                    9465
# 6356                    12141    II - Cagayan Valley                    6500
# 10200                   12911  VII - Central Visayas                   15909
#
#        Clothing, Footwear and Other Wear Expenditure  \
# 9474                                             500
# 22638                                              0
# 31209                                            125
# 6356                                              80
# 10200                                            160
#
#        Housing and water Expenditure  Imputed House Rental Value  \
# 9474                            5250                        3600
# 22638                           2550                        1800
# 31209                           2112                        1200
# 6356                            3810                        2400
# 10200                           4668                        3000
#
#        Medical Care Expenditure  Transportation Expenditure  \
# 9474                         55                         390
# 22638                         0                         360
# 31209                        23                          42
# 6356                        610                         300
# 10200                        90                         858
#
#        Communication Expenditure  Education Expenditure  \
# 9474                           0                      0
# 22638                          0                      0
# 31209                          0                      0
# 6356                           0                      0
# 10200                          0                      0
#
#        Miscellaneous Goods and Services Expenditure  \
# 9474                                           1236
# 22638                                             0
# 31209                                             0
# 6356                                            432
# 10200                                          1038
#
#        Crop Farming and Gardening expenses Household Head Sex  \
# 9474                                  2696             Female
# 22638                                    0             Female
# 31209                                    0               Male
# 6356                                     0             Female
# 10200                                 7188               Male
#
#       Household Head Highest Grade Completed Household Head Occupation  \
# 9474                                 Grade 4    Farmhands and laborers
# 22638                    Second Year College                       NaN
# 31209                    Elementary Graduate    Farmhands and laborers
# 6356                      No Grade Completed                       NaN
# 10200                    Elementary Graduate              Corn farmers
#
#           Household Head Class of Worker  Vice Expenditures  \
# 9474    Worked for private establishment                387
# 22638                                NaN                  0
# 31209   Worked for private establishment                  0
# 6356                                 NaN                  0
# 10200  Self-employed wihout any employee                308
#
#        Discretionary Expenses  New Total Food Expenditure  \
# 9474                     2620                        8359
# 22638                     250                       10746
# 31209                    3640                        8354
# 6356                        0                        6509
# 10200                     325                       13274
#
#       New Highest Household Head Grade Completed
# 9474                                   Preschool
# 22638                                High School
# 31209                               Grade School
# 6356                          No Grade Completed
# 10200                               Grade School

# %% [markdown]
# #### New columns:
# - Vice Expenditures: Sum of Alcoholic Beverages Expenditure & Tobacco Expenditure
# - Discretionary Expenses: Sum of restaurant & hotels expenditure and Special Occasions Expenditure
# - New Total Food Expenditure: Sum of Bread & Cereal Expenditure, Total Rice Expenditure, Meat Expenditure, Total Fish and marine products expenditure, Fruit expenditure and Vegetable expenditure
# - New Highest Household Head Grade Completed: Simplifies the data of Household head highest grade completed
#
# #### Data is sorted from lowest total household income to highest household income

# %% [markdown]
# # Data Demographic

# %% [markdown]
# #### Number of households in the dataset

# %%
len(new_df['Total Household Income'])
# Out:
# 41544

# %% [markdown]
# #### Number of households per region

# %%
sns.countplot(y = 'Region',data = new_df, palette="YlGnBu")
plt.title('Number of Households per Region')
plt.show()

# %% [markdown]
# #### Pie Chart of the number of Male and Females in the household

# %% [markdown]
# #### Average Income per Region

# %%
sns.barplot(x="Total Household Income", y="Region", data=new_df ,palette="YlGnBu")
plt.title('Average Income per Region')
plt.show()

# %% [markdown]
# # Data Analysis

# %% [markdown]
# #### Highest Grade Completed compared to the average total household income

# %%
width = 10
height = 8
sns.set(rc = {'figure.figsize':(width, height)})
sns.barplot(y="Total Household Income", x="New Highest Household Head Grade Completed", data=new_df, palette='YlGnBu')
plt.title('Highest Grade Completed and the Average total household income')
# Out:
# Text(0.5, 1.0, 'Highest Grade Completed and the Average total household income')

# %% [markdown]
# ## Transportation Expenditure and Region

# %%
sns.barplot(x = new_df['Transportation Expenditure'],y = new_df['Region'], data = new_df,palette = 'YlGnBu')
plt.title('Transportation Expenditure and Region')
plt.show()

# %% [markdown]
# ### Number of Automobiles in NCR, Calabarzon, Central Luzon, Davao Region

# %%
def car_sum(place):
    return new_df.loc[new_df['Region'] == place]['Number of Car, Jeep, Van'].sum()

def motor_sum(place):
    return new_df.loc[new_df['Region'] == place]['Number of Motorcycle/Tricycle'].sum()

def boat_sum(place):
    return new_df.loc[new_df['Region'] == place]['Number of Motorized Banca'].sum()

cars = [car_sum('NCR'),car_sum('IVA - CALABARZON'),car_sum('III - Central Luzon'),car_sum('XI - Davao Region')]
motor = [motor_sum('NCR'),motor_sum('IVA - CALABARZON'),motor_sum('III - Central Luzon'),motor_sum('XI - Davao Region')]
boat = [boat_sum('NCR'),boat_sum('IVA - CALABARZON'),boat_sum('III - Central Luzon'),boat_sum('XI - Davao Region')]

# %%
auto_plot = pd.DataFrame({'Number of Cars/Jeep/Van': cars,'Number of Motorcycles/Tricycles': motor,'Number of motorized boats': boat},index = ['NCR','Calabarzon','Central Luzon','Davao Region'])
auto_plot.plot(kind = 'bar',stacked = True, color = ['#345590','#51a9b3','#deeaba'])
plt.xlabel ('Region')
plt.ylabel ('Number of Cars')
plt.title ('Number of Automobiles in NCR, Calabarzon, Central Luzon and Davao Region')
plt.show ()

# %% [markdown]
# ### Number of Cars vs Transportation Expenditure

# %%
sns.boxplot(x ='Number of Car, Jeep, Van', y ='Transportation Expenditure', data = new_df, palette = 'YlGnBu')
plt.title('Number of Cars vs. Transportation Expenditure')
plt.show()

# %% [markdown]
# ## Male Household and Female Household

# %% [markdown]
# ### Total household income of Male and Female Househol

# %%
sns.boxplot(y ='Total Household Income', x ='Household Head Sex', data = new_df)
plt.show()

# %%
sns.barplot(y = new_df['Total Household Income'],x = new_df['Household Head Sex'],palette = 'YlGnBu')
plt.title('Household Head Sex and Average Total Household Income')
plt.show()

# %%
sns.countplot(x='New Highest Household Head Grade Completed', hue='Household Head Sex', data=new_df, palette = 'YlGnBu')
plt.xlabel('Highest Grade Completed')
plt.ylabel('Count')
plt.title('Comparison of Highest Grade Completed by Male and Female Household Heads')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Expenditures of Male and Female Household

# %%
exp_df = new_df.loc[:,['New Total Food Expenditure',
        'Clothing, Footwear and Other Wear Expenditure',
       'Housing and water Expenditure','Medical Care Expenditure', 'Transportation Expenditure',
       'Communication Expenditure', 'Education Expenditure',
       'Miscellaneous Goods and Services Expenditure', 'Crop Farming and Gardening expenses',
        'Discretionary Expenses','Vice Expenditures','Household Head Sex']]
m_exp = exp_df.loc[(exp_df['Household Head Sex'] == 'Male')]
f_exp = exp_df.loc[(exp_df['Household Head Sex'] == 'Female')]
def exp_average(df):
    average = []
    for col in df:
        if col != 'Household Head Sex':
            average.append(df[col].mean())
    return average
expenditure = []
for col in exp_df:
    if col != 'Household Head Sex':
        expenditure.append(col)

# %%
df1=pd.DataFrame({'x':expenditure,'y':exp_average(m_exp)})
df2=pd.DataFrame({'x':expenditure,'y':exp_average(f_exp)})
df1['hue']= 'Male'
df2['hue']= 'Female'
res=pd.concat([df1,df2])
sns.barplot(x='y',y='x',data=res,hue='hue',palette = 'YlGnBu')
plt.title('Expenditures of Male and Female Household')
plt.xlabel('')
plt.ylabel("")
plt.show()

# %%
sns.barplot(x='Household Head Sex', y='Vice Expenditures', data=new_df, palette = 'YlGnBu')
plt.xlabel('Household Head Sex')
plt.ylabel('Vice Expenditures')
plt.title('Comparison of Vice Expenditures by Male and Female Household Heads')
plt.show()

# %%
sns.barplot(x='New Highest Household Head Grade Completed', y='Vice Expenditures', hue='Household Head Sex', data=new_df, palette = 'YlGnBu')
plt.xlabel('Highest Grade Completed')
plt.ylabel('Vice Expenditures')
plt.title('Comparison of Vice Expenditures by Highest Grade Completed and Household Head Sex')
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(x='New Highest Household Head Grade Completed', y='Medical Care Expenditure', hue='Household Head Sex', data=new_df, palette = 'YlGnBu')
plt.xlabel('Highest Grade Completed')
plt.ylabel('Medical Care Expenditure')
plt.title('Comparison of Medical Care Expenditure by Highest Grade Completed and Household Head Sex')
plt.xticks(rotation=45)
plt.show()

# %%
f_df = new_df[new_df['Household Head Sex'] == 'Female']
f_grade_counts = f_df['New Highest Household Head Grade Completed'].value_counts()
m_df = new_df[new_df['Household Head Sex'] == 'Male']
m_grade_counts = m_df['New Highest Household Head Grade Completed'].value_counts()


plt.figure(figsize=(8, 6))
sns.set_palette('YlGnBu')
fig, axes = plt.subplots(1, 2, figsize=(12, 6), sharey=True, gridspec_kw={'wspace': 0.8})

axes[0].set_title("New Highest Household Grade Completed (Female Household Heads)")
f_grade_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, wedgeprops={'edgecolor': 'black'}, ax=axes[0])
axes[0].axis('equal')
axes[0].set_ylabel('')
axes[0].legend(title='Grade', bbox_to_anchor=(1, 0.5), loc='center left')


axes[1].set_title("New Highest Household Grade Completed (Male Household Heads)")
m_grade_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, wedgeprops={'edgecolor': 'black'}, ax=axes[1])
axes[1].axis('equal')
axes[1].set_ylabel('')
axes[1].legend(title='Grade', bbox_to_anchor=(1, 0.5), loc='center left')

plt.show()

# %%
expenditure_columns = ['Total Food Expenditure', 'Clothing, Footwear and Other Wear Expenditure',
                       'Housing and water Expenditure', 'Imputed House Rental Value',
                       'Medical Care Expenditure', 'Transportation Expenditure', 'Communication Expenditure',
                       'Education Expenditure', 'Miscellaneous Goods and Services Expenditure',
                       'Crop Farming and Gardening expenses']

f_expenditure_total = f_df[expenditure_columns].sum()
m_expenditure_total = m_df[expenditure_columns].sum()

fig, axes = plt.subplots(1, 2, figsize=(12, 6)) 

axes[0].set_title("Expenditures of Female Household Heads")
f_expenditure_total.plot(kind='pie', autopct='%1.1f%%', startangle=90, wedgeprops={'edgecolor': 'black'}, ax=axes[0])
axes[0].axis('equal')
axes[0].set_ylabel('')


axes[1].set_title("Expenditures of Male Household Heads")
m_expenditure_total.plot(kind='pie', autopct='%1.1f%%', startangle=90, wedgeprops={'edgecolor': 'black'}, ax=axes[1])
axes[1].axis('equal')
axes[1].set_ylabel('')


plt.subplots_adjust(wspace=0.4)  
plt.show()

# %%
df = pd.DataFrame(pd.read_csv('testingnewdf.csv'))
df['Household Head Class of Worker'].fillna('N/A', inplace=True)
incomeclass = df.groupby(['Household Head Class of Worker']).mean()
incomeclass = incomeclass.round(2)
headclass = incomeclass.drop(columns=incomeclass.columns[0], axis=1)
for ind in headclass.index:
    fig, ax = plt.subplots(1,1)
    fig.set_size_inches(5,5)
    headclass.loc[ind].plot(kind='pie', title=ind, autopct='%1.1f%%', textprops={'fontsize': 9})
    ax.set_ylabel('')
    ax.set_xlabel('')
# Out:
# /var/folders/dv/jw1k2dks3dq96dyd86x6dt580000gn/T/ipykernel_35442/1754430518.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   incomeclass = df.groupby(['Household Head Class of Worker']).mean()

# %%
expenditure_columns = ['Total Food Expenditure', 'Clothing, Footwear and Other Wear Expenditure',
                       'Housing and water Expenditure', 'Imputed House Rental Value',
                       'Medical Care Expenditure', 'Transportation Expenditure', 'Communication Expenditure',
                       'Education Expenditure', 'Miscellaneous Goods and Services Expenditure',
                       'Crop Farming and Gardening expenses']

expenditure_total = new_df[expenditure_columns].sum()

plt.figure(figsize=(8, 6))
sns.set_palette('pastel')
plt.title("Expenditures of All Household Heads")

expenditure_total.plot(kind='pie', autopct='%1.1f%%', startangle=90, wedgeprops={'edgecolor': 'black'})

plt.axis('equal') 

plt.ylabel('') 

plt.show()

# %%
sns.scatterplot(x= new_df['Total Household Income'],y = new_df['Vice Expenditures'])
# Out:
# <Axes: xlabel='Total Household Income', ylabel='Vice Expenditures'>

# %%
new_df.corr()
# Out:
# /var/folders/dv/jw1k2dks3dq96dyd86x6dt580000gn/T/ipykernel_16634/4065070317.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#
# Total Household Income                                       0.589402
# Clothing, Footwear and Other Wear Expenditure                0.479387
# Housing and water Expenditure                                0.454925
# Imputed House Rental Value                                   0.343737
# Medical Care Expenditure                                     0.178907
# Transportation Expenditure                                   0.526353
# Communication Expenditure                                    0.572486
# Education Expenditure                                        0.340122
# Miscellaneous Goods and Services Expenditure                 0.545577
# Crop Farming and Gardening expenses                         -0.004953
# Vice Expenditures                                            0.126892
# Discretionary Expenses                                       1.000000
# New Total Food Expenditure                                   0.357058
#
#                                                New Total Food Expenditure
# Total Household Income                                           0.472256
# Clothing, Footwear and Other Wear Expenditure                    0.389461
# Housing and water Expenditure                                    0.315671
# Imputed House Rental Value                                       0.228371
# Medical Care Expenditure                                         0.125583
# Transportation Expenditure                                       0.380584
# Communication Expenditure                                        0.399208
# Education Expenditure                                            0.267422
# Miscellaneous Goods and Services Expenditure                     0.410178
# Crop Farming and Gardening expenses                              0.089709
# Vice Expenditures                                                0.222802
# Discretionary Expenses                                           0.357058
# New Total Food Expenditure                                       1.000000

# %%
sns.heatmap(new_df.corr(),annot=True)
# Out:
# /var/folders/dv/jw1k2dks3dq96dyd86x6dt580000gn/T/ipykernel_16634/1407173483.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(new_df.corr(),annot=True)
# <Axes: >

# %%
grade_counts = new_df['New Highest Household Head Grade Completed'].value_counts()

plt.figure(figsize=(8, 6))
sns.set_palette('pastel')  
plt.title("Highest Household Grade Completed")


grade_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, wedgeprops={'edgecolor': 'black'})

plt.axis('equal') 

plt.legend(title='Grade')
plt.ylabel('') 

plt.show()

# %%
new_df
# Out:
#        Total Household Income                  Region  Total Food Expenditure  \
# 9474                    11285   VII - Central Visayas                   14709
# 22638                   11988                     CAR                    6781
# 31209                   12039        V - Bicol Region                    9465
# 6356                    12141     II - Cagayan Valley                    6500
# 10200                   12911   VII - Central Visayas                   15909
# ...                       ...                     ...                     ...
# 39302                 6452314                     NCR                  293880
# 9382                  7082152   VII - Central Visayas                  219345
# 30865                 9952913  VIII - Eastern Visayas                  367772
# 1238                 11639365    VI - Western Visayas                  280597
# 2139                 11815988    VI - Western Visayas                  286736
#
#        Clothing, Footwear and Other Wear Expenditure  \
# 9474                                             500
# 22638                                              0
# 31209                                            125
# 6356                                              80
# 10200                                            160
# ...                                              ...
# 39302                                          19569
# 9382                                           71234
# 30865                                         212925
# 1238                                           30025
# 2139                                           41326
#
#        Housing and water Expenditure  Imputed House Rental Value  \
# 9474                            5250                        3600
# 22638                           2550                        1800
# 31209                           2112                        1200
# 6356                            3810                        2400
# 10200                           4668                        3000
# ...                              ...                         ...
# 39302                        1663812                     1500000
# 9382                          331248                      210000
# 30865                         606798                      390000
# 1238                          292098                      240000
# 2139                          156600                       48000
#
#        Medical Care Expenditure  Transportation Expenditure  \
# 9474                         55                         390
# 22638                         0                         360
# 31209                        23                          42
# 6356                        610                         300
# 10200                        90                         858
# ...                         ...                         ...
# 39302                     11954                       52860
# 9382                      14321                       20844
# 30865                    289040                      161106
# 1238                      38615                       66570
# 2139                     198540                      217002
#
#        Communication Expenditure  Education Expenditure  \
# 9474                           0                      0
# 22638                          0                      0
# 31209                          0                      0
# 6356                           0                      0
# 10200                          0                      0
# ...                          ...                    ...
# 39302                      73470                  78450
# 9382                       17400                 149862
# 30865                      48858                  22565
# 1238                       43458                 102500
# 2139                       92988                 194000
#
#        Miscellaneous Goods and Services Expenditure  \
# 9474                                           1236
# 22638                                             0
# 31209                                             0
# 6356                                            432
# 10200                                          1038
# ...                                             ...
# 39302                                         75906
# 9382                                          64434
# 30865                                        317712
# 1238                                          50664
# 2139                                         146706
#
#        Crop Farming and Gardening expenses Household Head Sex  \
# 9474                                  2696             Female
# 22638                                    0             Female
# 31209                                    0               Male
# 6356                                     0             Female
# 10200                                 7188               Male
# ...                                    ...                ...
# 39302                                    0               Male
# 9382                                     0               Male
# 30865                                    0               Male
# 1238                                     0               Male
# 2139                                     0               Male
#
#             Household Head Highest Grade Completed  \
# 9474                                       Grade 4
# 22638                          Second Year College
# 31209                          Elementary Graduate
# 6356                            No Grade Completed
# 10200                          Elementary Graduate
# ...                                            ...
# 39302                   Security Services Programs
# 9382   Engineering and Engineering Trades Programs
# 30865         Business and Administration Programs
# 1238   Engineering and Engineering Trades Programs
# 2139   Agriculture, Forestry, and Fishery Programs
#
#                                Household Head Occupation  \
# 9474                              Farmhands and laborers
# 22638                                                NaN
# 31209                             Farmhands and laborers
# 6356                                                 NaN
# 10200                                       Corn farmers
# ...                                                  ...
# 39302  General managers/managing proprietors in whole...
# 9382                             Street ambulant vendors
# 30865  General managers/managing proprietors in whole...
# 1238   General managers/managing proprietors in whole...
# 2139   General managers/managing proprietors in const...
#
#                          Household Head Class of Worker  Vice Expenditures  \
# 9474                   Worked for private establishment                387
# 22638                                               NaN                  0
# 31209                  Worked for private establishment                  0
# 6356                                                NaN                  0
# 10200                 Self-employed wihout any employee                308
# ...                                                 ...                ...
# 39302  Employer in own family-operated farm or business               7988
# 9382                  Self-employed wihout any employee                  0
# 30865  Employer in own family-operated farm or business               5670
# 1238   Employer in own family-operated farm or business               3160
# 2139   Employer in own family-operated farm or business                  0
#
#        Discretionary Expenses  New Total Food Expenditure  \
# 9474                     2620                        8359
# 22638                     250                       10746
# 31209                    3640                        8354
# 6356                        0                        6509
# 10200                     325                       13274
# ...                       ...                         ...
# 39302                   71550                      199805
# 9382                    80288                      107823
# 30865                   67690                      281657
# 1238                   144900                      213164
# 2139                   145000                      240071
#
#       New Highest Household Head Grade Completed
# 9474                                   Preschool
# 22638                                High School
# 31209                               Grade School
# 6356                          No Grade Completed
# 10200                               Grade School
# ...                                          ...
# 39302                             College and up
# 9382                              College and up
# 30865                             College and up
# 1238                              College and up
# 2139                              College and up
#
# [41544 rows x 20 columns]
